# %% [markdown]
# # Running the Kmeans for clusters: 3

# %%
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np

# %%
data = pd.read_csv('FinalDataframe_3.csv')

# %%
## have to also drop na
data = data.dropna()

# %%
asian = data[['Total!!Population of one race!!Asian',
       'Total!!Population of one race!!Asian!!Asian Indian',
       'Total!!Population of one race!!Asian!!Chinese (including Taiwanese)',
       'Total!!Population of one race!!Asian!!Filipino',
       'Total!!Population of one race!!Asian!!Japanese',
       'Total!!Population of one race!!Asian!!Korean',
       'Total!!Population of one race!!Asian!!Vietnamese',
       'Total!!Population of one race!!Asian!!Other Asian']]
data['All Asian'] = asian.mean(axis=1, skipna=True)
data = data.drop(columns = ['Total!!Population of one race!!Asian',
       'Total!!Population of one race!!Asian!!Asian Indian',
       'Total!!Population of one race!!Asian!!Chinese (including Taiwanese)',
       'Total!!Population of one race!!Asian!!Filipino',
       'Total!!Population of one race!!Asian!!Japanese',
       'Total!!Population of one race!!Asian!!Korean',
       'Total!!Population of one race!!Asian!!Vietnamese',
       'Total!!Population of one race!!Asian!!Other Asian'])

data['Pac Island'] = data[['Total!!Population of one race!!Native Hawaiian and Other Pacific Islander',
       'Total!!Population of one race!!Native Hawaiian and Other Pacific Islander!!Native Hawaiian',
       'Total!!Population of one race!!Native Hawaiian and Other Pacific Islander!!Guamanian or Chamorro',
       'Total!!Population of one race!!Native Hawaiian and Other Pacific Islander!!Samoan',
       'Total!!Population of one race!!Native Hawaiian and Other Pacific Islander!!Other Pacific Islander']].mean(axis=1, skipna=True)
data = data.drop(columns = ['Total!!Population of one race!!Native Hawaiian and Other Pacific Islander',
       'Total!!Population of one race!!Native Hawaiian and Other Pacific Islander!!Native Hawaiian',
       'Total!!Population of one race!!Native Hawaiian and Other Pacific Islander!!Guamanian or Chamorro',
       'Total!!Population of one race!!Native Hawaiian and Other Pacific Islander!!Samoan',
       'Total!!Population of one race!!Native Hawaiian and Other Pacific Islander!!Other Pacific Islander'])

data['Other Race'] = data[['Total!!Population of one race!!Some Other Race',
       'Total!!Population of Two or More Races',
       'Total!!Population of Two or More Races!!White; American Indian and Alaska Native',
       'Total!!Population of Two or More Races!!White; Asian',
       'Total!!Population of Two or More Races!!White; Black or African American',
       'Total!!Population of Two or More Races!!White; Some Other Race']].mean(axis=1, skipna=True)
data = data.drop(columns = ['Total!!Population of one race!!Some Other Race',
       'Total!!Population of Two or More Races',
       'Total!!Population of Two or More Races!!White; American Indian and Alaska Native',
       'Total!!Population of Two or More Races!!White; Asian',
       'Total!!Population of Two or More Races!!White; Black or African American',
       'Total!!Population of Two or More Races!!White; Some Other Race'])

# %% [markdown]
# ## build per capita

# %%
data['num_hospitals_pt'] = data['num_hospitals'] / data['Total']
data['num_licensed_beds_pt'] = data['num_licensed_beds'] / data['Total']
data['num_staffed_beds_pt'] = data['num_staffed_beds'] / data['Total']
data['num_icu_beds_pt'] = data['num_icu_beds'] / data['Total']
data['adult_icu_beds_pt'] = data['adult_icu_beds'] / data['Total']
data['pedi_icu_beds_pt'] = data['pedi_icu_beds'] / data['Total']
data['potential_increase_in_bed_capac_pt'] = data['potential_increase_in_bed_capac'] / data['Total']
data['bed_utilization_pt'] = data['bed_utilization'] / data['Total']
data['avg_ventilator_usage_pt'] = data['avg_ventilator_usage'] / data['Total']

# %%
#for X, or what we're clustering, we are removing outcomes y, such as case and death totals
#Also removing strings; can't k-means cluster on these
#Also removing columns Unnamed, they seem to be artifacts from data cleaning/combining multiple datasets?
X = data.drop(['Unnamed: 0', 'Unnamed: 0.1','NAME',  'cases_total', 'fips_final',
       'deaths_total', 'cases_per_capita', 'deaths_per_capita',
       'case_fatality_rate', 'Unnamed: 0.1.1', 'county', 'population','STATEFP', 'COUNTYFP',
       'CountyName', 'StateName', 'State','num_hospitals', 'num_licensed_beds','num_staffed_beds','num_icu_beds',
        'adult_icu_beds','pedi_icu_beds', 'potential_increase_in_bed_capac','bed_utilization','avg_ventilator_usage',
         'federal.guidelines',   'foreign.travel.ban'  ], axis=1)
y = data[["cases_total", "deaths_total", "cases_per_capita", "deaths_per_capita", "case_fatality_rate"]]


## standardize
X_n = (X - X.mean(axis=0)) / X.std(axis=0)

# %%
#set number of clusters
kmeans = KMeans(n_clusters=3, random_state=263).fit(X_n)

#Run the clustering algorithm
model = kmeans.fit(X_n)
model

#Generate cluster predictions and store in y_hat
y_hat = kmeans.predict(X_n)

#function that creates a dataframe with a column for cluster number
cluster_centers = kmeans.cluster_centers_

def kmean_col(X, cluster_centers):
        cols = list(X)
        cols.append('cluster')
        
# Zip with a column called 'cluster' (index)
        Z = [np.append(A, index) for index, A in enumerate(cluster_centers)]
    
# Convert to pandas data frame for plotting
        P = pd.DataFrame(Z, columns=cols)
        P['cluster'] = P['cluster'].astype(int)
        return P
    
P = kmean_col(X_n, cluster_centers)
P
# Out:
#    dem_to_rep_ratio  stay.at.home  X.50.gatherings  X.500.gatherings  \
# 0          0.758409     -0.386057        -0.275036         -0.179353
# 1          1.371737     -0.826346        -0.124767         -0.119798
# 2         -0.245025      0.127334         0.081272          0.053780
#
#    public.schools  restaurant.dine.in  entertainment.gym  Total!!Male  \
# 0       -0.053478           -0.300056          -0.396542     0.708305
# 1        0.373038           -0.318761          -0.552175     5.838073
# 2        0.007715            0.092383           0.124754    -0.321600
#
#    Total!!Female     Total  ...  num_hospitals_pt  num_licensed_beds_pt  \
# 0       0.715334  0.711998  ...         -0.441232              0.111568
# 1       5.806225  5.822667  ...         -0.481377              0.031917
# 2      -0.322964 -0.322344  ...          0.136106             -0.032587
#
#    num_staffed_beds_pt  num_icu_beds_pt  adult_icu_beds_pt  pedi_icu_beds_pt  \
# 0             0.180304         0.030589           0.030589          0.602089
# 1             0.148023         0.104698           0.104698          0.852632
# 2            -0.054627        -0.010888          -0.010888         -0.189710
#
#    potential_increase_in_bed_capac_pt  bed_utilization_pt  \
# 0                           -0.079017           -0.395561
# 1                           -0.204641           -0.493808
# 2                            0.026785            0.123285
#
#    avg_ventilator_usage_pt  cluster
# 0                -0.568662        0
# 1                -0.903419        1
# 2                 0.181175        2
#
# [3 rows x 38 columns]

# %% [markdown]
# ## separating K-means datasets

# %%
X_n['label'] = kmeans.labels_ # result for K-means
whole = pd.concat([X_n, y], axis=1)

counts_1 = X_n['label'].value_counts() # kmeans
counts_1
# Out:
# 2    786
# 0    225
# 1     16
# Name: label, dtype: int64

# %%
whole.columns
# Out:
# Index(['dem_to_rep_ratio', 'stay.at.home', 'X.50.gatherings',
#        'X.500.gatherings', 'public.schools', 'restaurant.dine.in',
#        'entertainment.gym', 'Total!!Male', 'Total!!Female', 'Total',
#        'Total!!Population of one race', 'Total!!Population of one race!!White',
#        'Total!!Population of one race!!Black or African American',
#        'Total!!Population of one race!!American Indian and Alaska Native',
#        'mob_retail', 'mob_grocery', 'mob_parks', 'mob_transit',
#        'mob_workplace', 'mob_residential', '0-17', '18-44', '45-64', '65-74',
#        '75+', 'All Asian', 'Pac Island', 'Other Race', 'num_hospitals_pt',
#        'num_licensed_beds_pt', 'num_staffed_beds_pt', 'num_icu_beds_pt',
#        'adult_icu_beds_pt', 'pedi_icu_beds_pt',
#        'potential_increase_in_bed_capac_pt', 'bed_utilization_pt',
#        'avg_ventilator_usage_pt', 'label', 'cases_total', 'deaths_total',
#        'cases_per_capita', 'deaths_per_capita', 'case_fatality_rate'],
#       dtype='object')

# %%
whole
# Out:
#       dem_to_rep_ratio  stay.at.home  X.50.gatherings  X.500.gatherings  \
# 1            -0.564591      1.389090        -0.175407         -1.090803
# 3            -0.539953      1.389090        -0.175407         -1.090803
# 4            -0.722049      1.389090        -0.175407         -1.090803
# 6            -0.062311      1.389090        -0.175407         -1.090803
# 7            -0.416318      1.389090        -0.175407         -1.090803
# ...                ...           ...              ...               ...
# 2289         -0.442881      0.033195        -0.175407          0.359231
# 2292         -0.633705      0.033195        -0.175407          0.359231
# 2293         -0.354053      0.033195        -0.175407          0.359231
# 2294         -0.654003      0.033195        -0.175407          0.359231
# 2295         -0.538833      0.033195        -0.175407          0.359231
#
#       public.schools  restaurant.dine.in  entertainment.gym  Total!!Male  \
# 1          -0.846132            0.169535           1.645564    -0.046878
# 3          -0.846132            0.169535           1.645564    -0.460164
# 4          -0.846132            0.169535           1.645564    -0.373842
# 6          -0.846132            0.169535           1.645564    -0.473402
# 7          -0.846132            0.169535           1.645564    -0.218976
# ...              ...                 ...                ...          ...
# 2289        1.011650            0.169535          -0.272462    -0.418623
# 2292        1.011650            0.169535          -0.272462    -0.502818
# 2293        1.011650            0.169535          -0.272462    -0.279715
# 2294        1.011650            0.169535          -0.272462    -0.476283
# 2295        1.011650            0.169535          -0.272462    -0.322137
#
#       Total!!Female     Total  ...  pedi_icu_beds_pt  \
# 1         -0.044805 -0.045827  ...         -0.466281
# 3         -0.469788 -0.465145  ...         -0.466281
# 4         -0.375230 -0.374605  ...         -0.466281
# 6         -0.467236 -0.470323  ...         -0.466281
# 7         -0.208051 -0.213430  ...         -0.466281
# ...             ...       ...  ...               ...
# 2289      -0.420932 -0.419863  ...         -0.466281
# 2292      -0.502825 -0.502895  ...         -0.466281
# 2293      -0.288110 -0.284042  ...         -0.466281
# 2294      -0.479116 -0.477799  ...         -0.466281
# 2295      -0.331379 -0.326903  ...         -0.466281
#
#       potential_increase_in_bed_capac_pt  bed_utilization_pt  \
# 1                              -0.430859           -0.339586
# 3                              -0.086634            0.528261
# 4                              -0.579607           -0.029220
# 6                               0.930402           -0.016734
# 7                              -0.093725           -0.308938
# ...                                  ...                 ...
# 2289                           -0.213597           -0.332612
# 2292                           -0.184118            1.264053
# 2293                           -0.136308           -0.200939
# 2294                           -0.392435            0.138033
# 2295                            0.049223           -0.029557
#
#       avg_ventilator_usage_pt  label  cases_total  deaths_total  \
# 1                   -0.737095      2          188             4
# 3                   -0.058992      2           42             0
# 4                   -0.240605      2           40             0
# 6                    1.017112      2          114             1
# 7                   -0.089529      2          105             3
# ...                       ...    ...          ...           ...
# 2289                 0.069859      2          128             4
# 2292                 1.457618      2           11             1
# 2293                -0.059762      2          104             1
# 2294                 1.328104      2            6             0
# 2295                 0.135632      2           38             0
#
#       cases_per_capita  deaths_per_capita  case_fatality_rate
# 1             0.000842           0.000018         0.021276596
# 3             0.001876           0.000000                   0
# 4             0.000692           0.000000                   0
# 6             0.005862           0.000051          0.00877193
# 7             0.000924           0.000026         0.028571429
# ...                ...                ...                 ...
# 2289          0.003260           0.000102             0.03125
# 2292          0.001303           0.000118         0.090909091
# 2293          0.001045           0.000010         0.009615385
# 2294          0.000303           0.000000                   0
# 2295          0.000476           0.000000                   0
#
# [1027 rows x 43 columns]

# %%
c = whole[['num_hospitals_pt',
       'num_licensed_beds_pt', 'num_staffed_beds_pt', 'num_icu_beds_pt',
       'adult_icu_beds_pt', 'pedi_icu_beds_pt',
       'potential_increase_in_bed_capac_pt', 'bed_utilization_pt',
       'avg_ventilator_usage_pt']]

# %%
whole_2 = pd.concat([whole, c], axis=1)

# %%
## Just to view progress...
whole_2
# Out:
#       dem_to_rep_ratio  stay.at.home  X.50.gatherings  X.500.gatherings  \
# 1            -0.564591      1.389090        -0.175407         -1.090803
# 3            -0.539953      1.389090        -0.175407         -1.090803
# 4            -0.722049      1.389090        -0.175407         -1.090803
# 6            -0.062311      1.389090        -0.175407         -1.090803
# 7            -0.416318      1.389090        -0.175407         -1.090803
# ...                ...           ...              ...               ...
# 2289         -0.442881      0.033195        -0.175407          0.359231
# 2292         -0.633705      0.033195        -0.175407          0.359231
# 2293         -0.354053      0.033195        -0.175407          0.359231
# 2294         -0.654003      0.033195        -0.175407          0.359231
# 2295         -0.538833      0.033195        -0.175407          0.359231
#
#       public.schools  restaurant.dine.in  entertainment.gym  Total!!Male  \
# 1          -0.846132            0.169535           1.645564    -0.046878
# 3          -0.846132            0.169535           1.645564    -0.460164
# 4          -0.846132            0.169535           1.645564    -0.373842
# 6          -0.846132            0.169535           1.645564    -0.473402
# 7          -0.846132            0.169535           1.645564    -0.218976
# ...              ...                 ...                ...          ...
# 2289        1.011650            0.169535          -0.272462    -0.418623
# 2292        1.011650            0.169535          -0.272462    -0.502818
# 2293        1.011650            0.169535          -0.272462    -0.279715
# 2294        1.011650            0.169535          -0.272462    -0.476283
# 2295        1.011650            0.169535          -0.272462    -0.322137
#
#       Total!!Female     Total  ...  case_fatality_rate  num_hospitals_pt  \
# 1         -0.044805 -0.045827  ...         0.021276596         -0.295633
# 3         -0.469788 -0.465145  ...                   0          0.152923
# 4         -0.375230 -0.374605  ...                   0         -0.388696
# 6         -0.467236 -0.470323  ...          0.00877193          0.237699
# 7         -0.208051 -0.213430  ...         0.028571429         -0.226262
# ...             ...       ...  ...                 ...               ...
# 2289      -0.420932 -0.419863  ...             0.03125         -0.234072
# 2292      -0.502825 -0.502895  ...         0.090909091          1.663590
# 2293      -0.288110 -0.284042  ...         0.009615385         -0.524020
# 2294      -0.479116 -0.477799  ...                   0          1.534584
# 2295      -0.331379 -0.326903  ...                   0          0.072735
#
#       num_licensed_beds_pt  num_staffed_beds_pt  num_icu_beds_pt  \
# 1                -0.368365            -0.228826        -0.015193
# 3                -0.653126            -0.764545        -0.489232
# 4                -1.179445            -1.156463        -0.803982
# 6                 0.268017            -0.160348         0.229650
# 7                 0.587078             0.778140        -0.135901
# ...                    ...                  ...              ...
# 2289              0.365233             0.566368         0.071585
# 2292              0.017336             0.119056         0.826946
# 2293             -0.306760            -0.308433        -0.538994
# 2294             -0.377550            -0.260580         0.714549
# 2295              1.007363             1.223926        -0.081561
#
#       adult_icu_beds_pt  pedi_icu_beds_pt  potential_increase_in_bed_capac_pt  \
# 1             -0.015193         -0.466281                           -0.430859
# 3             -0.489232         -0.466281                           -0.086634
# 4             -0.803982         -0.466281                           -0.579607
# 6              0.229650         -0.466281                            0.930402
# 7             -0.135901         -0.466281                           -0.093725
# ...                 ...               ...                                 ...
# 2289           0.071585         -0.466281                           -0.213597
# 2292           0.826946         -0.466281                           -0.184118
# 2293          -0.538994         -0.466281                           -0.136308
# 2294           0.714549         -0.466281                           -0.392435
# 2295          -0.081561         -0.466281                            0.049223
#
#       bed_utilization_pt  avg_ventilator_usage_pt
# 1              -0.339586                -0.737095
# 3               0.528261                -0.058992
# 4              -0.029220                -0.240605
# 6              -0.016734                 1.017112
# 7              -0.308938                -0.089529
# ...                  ...                      ...
# 2289           -0.332612                 0.069859
# 2292            1.264053                 1.457618
# 2293           -0.200939                -0.059762
# 2294            0.138033                 1.328104
# 2295           -0.029557                 0.135632
#
# [1027 rows x 52 columns]

# %%
whole_2.to_csv('CleanKmeanLassoDF.csv')

# %% [markdown]
# ## Created dataframe with kmeans labels. Now for Lassoing each cluster.

# %%
data = pd.read_csv('CleanKmeanLassoDF.csv')

# %% [markdown]
# ### This is the first cluster.

# %%
km_0 = data[data["label"]==0]
km_0
# Out:
#       Unnamed: 0  dem_to_rep_ratio  stay.at.home  X.50.gatherings  \
# 21            32          0.337700     -0.354204        -0.175407
# 28            41         -0.063626      1.389090        -0.175407
# 40            71          0.705376      0.614293        -0.985645
# 44            78          0.513859      0.614293        -0.985645
# 45            79         -0.163924      0.614293        -0.985645
# ...          ...               ...           ...              ...
# 983         2209         -0.025439     -0.741602         0.904910
# 992         2233          2.207863     -0.547903        -0.985645
# 1003        2254          1.457998     -0.547903        -0.985645
# 1006        2258         -0.059083     -0.547903        -0.985645
# 1016        2278         -0.264953     -0.547903        -0.985645
#
#       X.500.gatherings  public.schools  restaurant.dine.in  entertainment.gym  \
# 21           -1.090803       -0.846132            0.169535           1.645564
# 28           -1.090803       -0.846132            0.169535           1.645564
# 40           -0.262212       -0.846132            0.169535          -0.272462
# 44           -0.262212       -0.846132            0.169535          -0.272462
# 45           -0.262212       -0.846132            0.169535          -0.272462
# ...                ...             ...                 ...                ...
# 983           1.187821       -0.846132            2.029713           0.793108
# 992          -0.262212        0.082759           -0.574536          -0.698690
# 1003         -0.262212        0.082759           -0.574536          -0.698690
# 1006         -0.262212        0.082759           -0.574536          -0.698690
# 1016         -0.262212        0.082759           -0.574536          -0.698690
#
#       Total!!Male  Total!!Female  ...  case_fatality_rate  num_hospitals_pt.1  \
# 21       1.149617       1.262195  ...         0.048387097           -0.341189
# 28       0.539918       0.581672  ...          0.05400982           -0.449014
# 40      -0.167970      -0.175276  ...         0.081481481            0.019702
# 44       2.061291       2.046511  ...         0.066121842           -0.411919
# 45       0.533420       0.396057  ...         0.027777778           -0.474284
# ...           ...            ...  ...                 ...                 ...
# 983     -0.259694      -0.284368  ...         0.046728972           -0.104525
# 992      0.771228       0.746830  ...         0.049886621           -0.452860
# 1003     1.933804       2.001114  ...         0.059162621           -0.443970
# 1006    -0.052608      -0.068019  ...          0.02739726           -0.398350
# 1016     0.502193       0.498783  ...         0.054495913           -0.325150
#
#       num_licensed_beds_pt.1  num_staffed_beds_pt.1  num_icu_beds_pt.1  \
# 21                  1.873370               1.933640           1.412626
# 28                  0.794064               0.704052           1.407273
# 40                  0.110006               0.345625           0.768394
# 44                  0.256501               0.283459           0.153469
# 45                 -1.053514              -1.000198          -0.807967
# ...                      ...                    ...                ...
# 983                 3.499024               4.120033           2.985390
# 992                 0.660696               0.708771          -0.408002
# 1003                0.651428               0.572962           1.019874
# 1006                0.021412               0.160901           0.483331
# 1016               -0.066170              -0.327634          -0.536114
#
#       adult_icu_beds_pt.1  pedi_icu_beds_pt.1  \
# 21               1.412626            3.410953
# 28               1.407273            2.296788
# 40               0.768394            0.828680
# 44               0.153469            1.102296
# 45              -0.807967           -0.466281
# ...                   ...                 ...
# 983              2.985390            3.454663
# 992             -0.408002            2.050065
# 1003             1.019874            0.676551
# 1006             0.483331            0.354672
# 1016            -0.536114            0.377029
#
#       potential_increase_in_bed_capac_pt.1  bed_utilization_pt.1  \
# 21                                0.737955             -0.457079
# 28                                0.530916             -0.410610
# 40                               -0.394723             -0.323734
# 44                                0.065733             -0.478040
# 45                               -0.579607             -0.468531
# ...                                    ...                   ...
# 983                               0.418637             -0.111678
# 992                               0.209640             -0.437421
# 1003                              0.444274             -0.477173
# 1006                             -0.253553             -0.372530
# 1016                              0.463437             -0.427220
#
#       avg_ventilator_usage_pt.1
# 21                    -0.741775
# 28                    -0.705184
# 40                    -0.594250
# 44                    -0.889437
# 45                    -0.854393
# ...                         ...
# 983                    2.775796
# 992                   -0.709690
# 1003                  -0.858491
# 1006                  -0.455792
# 1016                  -0.858395
#
# [225 rows x 53 columns]

# %%
from sklearn.linear_model import enet_path
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import lasso_path
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

X = km_0.drop(['Unnamed: 0', 'cases_total', 
       'deaths_total', 'cases_per_capita', 'deaths_per_capita',
       'case_fatality_rate', 'num_hospitals_pt',
       'num_licensed_beds_pt', 'num_staffed_beds_pt', 'num_icu_beds_pt',
       'adult_icu_beds_pt', 'pedi_icu_beds_pt',
       'potential_increase_in_bed_capac_pt', 'bed_utilization_pt',
       'avg_ventilator_usage_pt',"label"], axis=1)
Y = km_0['cases_per_capita']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=263)

# 5-fold cross validation with lasso
np.random.seed(263)
lasso = Lasso(random_state=263, max_iter=100000, tol=0.0000001)
alphas = np.logspace(-5, -2, 30)
tuned_parameters = [{"alpha": alphas}]
n_folds = 5
clf = GridSearchCV(lasso, tuned_parameters, cv=n_folds)
clf.fit(X_train, y_train)
scores = clf.cv_results_["mean_test_score"]
scores_std = clf.cv_results_["std_test_score"]
# Best hyperparameter determined by lasso
print("The best hyperparameter chosen by lasso is {}.".format(clf.best_params_["alpha"]))
# Out:
# The best hyperparameter chosen by lasso is 0.0003562247890262444.

# %%
# First we import the necessary packages:
from itertools import cycle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import enet_path, lasso_path

eps = .01

alphas_lasso, coefs_lasso, _ = enet_path(
    X, Y, n_alphas = 10000, eps = eps, l1_ratio=1., fit_intercept=False)

plt.figure(1)
colors = cycle(['b', 'r', 'g', 'c', 'k'])
neg_log_alphas_lasso = np.log10(alphas_lasso)
for coef_l, c in zip(coefs_lasso, colors):
    l1 = plt.plot(neg_log_alphas_lasso, coef_l, c=c)
#    l2 = plt.plot(neg_log_alphas_ridge, coef_e, linestyle='--', c=c)

plt.xlabel('Log(alpha)')
plt.ylabel('coefficients')
plt.title('Lasso Paths')
plt.axis('tight')
plt.show()

# %%
# Top 30 important features determined by lasso
lm_lasso = Lasso(alpha=clf.best_params_["alpha"])
lm_lasso.fit(X_train, y_train)
coef_dict = {}
for coef, feat in zip(lm_lasso.coef_, X_train.columns):
    coef_dict[feat] = coef
print("The most important features determined by lasso are:")
allkm = sorted(coef_dict, key=coef_dict.get)[0:10]
print(allkm, "And the total samples in this cluster are:", len(X))
# Out:
# The most important features determined by lasso are:
# ['stay.at.home', 'X.50.gatherings', 'Pac Island', 'entertainment.gym', 'X.500.gatherings', 'public.schools', 'restaurant.dine.in', 'Total!!Male', 'Total!!Female', 'Total'] And the total samples in this cluster are: 225

# %%
allkm = list(allkm)
allkm.append('cases_per_capita')
allkm
km_0 = km_0[km_0.columns & allkm]
#Examining to see if it makes sense.
km_0
# Out:
#       stay.at.home  X.50.gatherings  X.500.gatherings  public.schools  \
# 21       -0.354204        -0.175407         -1.090803       -0.846132
# 28        1.389090        -0.175407         -1.090803       -0.846132
# 40        0.614293        -0.985645         -0.262212       -0.846132
# 44        0.614293        -0.985645         -0.262212       -0.846132
# 45        0.614293        -0.985645         -0.262212       -0.846132
# ...            ...              ...               ...             ...
# 983      -0.741602         0.904910          1.187821       -0.846132
# 992      -0.547903        -0.985645         -0.262212        0.082759
# 1003     -0.547903        -0.985645         -0.262212        0.082759
# 1006     -0.547903        -0.985645         -0.262212        0.082759
# 1016     -0.547903        -0.985645         -0.262212        0.082759
#
#       restaurant.dine.in  entertainment.gym  Total!!Male  Total!!Female  \
# 21              0.169535           1.645564     1.149617       1.262195
# 28              0.169535           1.645564     0.539918       0.581672
# 40              0.169535          -0.272462    -0.167970      -0.175276
# 44              0.169535          -0.272462     2.061291       2.046511
# 45              0.169535          -0.272462     0.533420       0.396057
# ...                  ...                ...          ...            ...
# 983             2.029713           0.793108    -0.259694      -0.284368
# 992            -0.574536          -0.698690     0.771228       0.746830
# 1003           -0.574536          -0.698690     1.933804       2.001114
# 1006           -0.574536          -0.698690    -0.052608      -0.068019
# 1016           -0.574536          -0.698690     0.502193       0.498783
#
#          Total  Pac Island  cases_per_capita
# 21    1.207261    0.007871          0.001506
# 28    0.561314   -0.029420          0.002957
# 40   -0.171725   -0.066711          0.003764
# 44    2.054047    1.294421          0.001285
# 45    0.463367    1.239416          0.001011
# ...        ...         ...               ...
# 983  -0.272330   -0.174856          0.001013
# 992   0.758885   -0.064847          0.000807
# 1003  1.968452    0.118813          0.003485
# 1006 -0.060484   -0.159007          0.000389
# 1016  0.500526   -0.097477          0.000908
#
# [225 rows x 11 columns]

# %% [markdown]
# ### This is the second cluster

# %%
km_1 = data[data["label"]==1]
km_1

from sklearn.linear_model import enet_path
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import lasso_path
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

X = km_1.drop(['Unnamed: 0', 'cases_total', 
       'deaths_total', 'cases_per_capita', 'deaths_per_capita',
       'case_fatality_rate', 'num_hospitals_pt',
       'num_licensed_beds_pt', 'num_staffed_beds_pt', 'num_icu_beds_pt',
       'adult_icu_beds_pt', 'pedi_icu_beds_pt',
       'potential_increase_in_bed_capac_pt', 'bed_utilization_pt',
       'avg_ventilator_usage_pt',"label"], axis=1)
Y = km_1['cases_per_capita']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=263)

# 5-fold cross validation with lasso
np.random.seed(263)
lasso = Lasso(random_state=263, max_iter=100000, tol=0.0000001)
alphas = np.logspace(-5, -2, 30)
tuned_parameters = [{"alpha": alphas}]
n_folds = 5
clf = GridSearchCV(lasso, tuned_parameters, cv=n_folds)
clf.fit(X_train, y_train)
scores = clf.cv_results_["mean_test_score"]
scores_std = clf.cv_results_["std_test_score"]
# Best hyperparameter determined by lasso
print("The best hyperparameter chosen by lasso is {}.".format(clf.best_params_["alpha"]))

# First we import the necessary packages:
from itertools import cycle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import enet_path, lasso_path

eps = .01

alphas_lasso, coefs_lasso, _ = enet_path(
    X, Y, n_alphas = 10000, eps = eps, l1_ratio=1., fit_intercept=False)

plt.figure(1)
colors = cycle(['b', 'r', 'g', 'c', 'k'])
neg_log_alphas_lasso = np.log10(alphas_lasso)
for coef_l, c in zip(coefs_lasso, colors):
    l1 = plt.plot(neg_log_alphas_lasso, coef_l, c=c)
#    l2 = plt.plot(neg_log_alphas_ridge, coef_e, linestyle='--', c=c)

plt.xlabel('Log(alpha)')
plt.ylabel('coefficients')
plt.title('Lasso Paths')
plt.axis('tight')
plt.show()

# Top 30 important features determined by lasso
lm_lasso = Lasso(alpha=clf.best_params_["alpha"])
lm_lasso.fit(X_train, y_train)
coef_dict = {}
for coef, feat in zip(lm_lasso.coef_, X_train.columns):
    coef_dict[feat] = coef
print("The most important features determined by lasso are:")
allkm = sorted(coef_dict, key=coef_dict.get)[0:10]
print(allkm, "And the total samples in this cluster are:", len(X))

allkm = list(allkm)
allkm.append('cases_per_capita')
allkm
km_1 = km_1[km_1.columns & allkm]
#Examining to see if it makes sense.
km_1
# Out:
# The best hyperparameter chosen by lasso is 0.0038566204211634724.
# The most important features determined by lasso are:
# ['Other Race', 'Pac Island', 'dem_to_rep_ratio', 'stay.at.home', 'X.50.gatherings', 'X.500.gatherings', 'public.schools', 'restaurant.dine.in', 'entertainment.gym', 'Total!!Male'] And the total samples in this cluster are: 16
#      dem_to_rep_ratio  stay.at.home  X.50.gatherings  X.500.gatherings  \
# 41           0.116277      0.614293        -0.985645         -0.262212
# 48           4.501856     -1.710099        -0.445486          0.152083
# 64           0.376045     -1.710099        -0.445486          0.152083
# 66           0.295463     -1.710099        -0.445486          0.152083
# 67           0.886342     -1.710099        -0.445486          0.152083
# 111          1.285175     -0.160504        -0.985645         -0.262212
# 131          1.035825     -0.547903        -0.985645         -0.262212
# 214          2.707541     -1.322700        -0.715566         -0.055065
# 442          1.431783     -0.741602         0.904910          1.187821
# 537          0.429550      0.807992         0.904910          1.187821
# 764          4.504972     -0.935302         0.634831          0.980674
# 847          0.501750     -0.741602         0.094672         -0.883655
# 862          0.921714     -0.935302         0.094672         -0.883655
# 871          0.469096     -0.741602         0.094672         -0.883655
# 904          0.010445     -0.741602         0.094672         -0.883655
# 956          2.473963     -0.935302         0.634831         -1.505098
#
#      public.schools  restaurant.dine.in  entertainment.gym  Total!!Male  \
# 41        -0.846132            0.169535          -0.272462     9.623615
# 48         0.547205           -1.318607          -1.124919     3.454064
# 64         0.547205           -1.318607          -1.124919     7.475437
# 66         0.547205           -1.318607          -1.124919     5.329843
# 67         0.547205           -1.318607          -1.124919     3.208011
# 111       -0.846132            0.541571          -0.059348     4.023769
# 131       -0.846132            0.541571          -0.059348     5.968291
# 214       -0.381687           -0.202500          -0.485576    12.987353
# 442       -0.846132           -0.946572          -0.911805     4.172057
# 537       -0.846132            0.541571          -0.059348     4.752694
# 764       -0.846132           -0.574536          -0.698690     3.342486
# 847        2.404987            0.169535          -0.272462     3.992967
# 862        2.404987            0.169535          -0.272462     5.767482
# 871        2.404987            0.169535          -0.272462    10.424120
# 904        2.404987            0.169535          -0.272462     4.242325
# 956       -0.381687           -0.574536          -0.698690     4.644647
#
#      Pac Island  Other Race  cases_per_capita
# 41     7.042875   10.965854          0.001059
# 48    11.715475    4.580134          0.001075
# 64     8.500965   10.052526          0.000900
# 66     6.188904    9.535436          0.001762
# 67    12.699965    4.149794          0.000725
# 111    0.629704    1.979236          0.002757
# 131    0.409685    2.476654          0.004818
# 214    1.387649   11.871451          0.008488
# 442    0.157036    1.362171          0.009897
# 537   12.485540    6.385130          0.001946
# 764    0.474013    2.145663          0.010126
# 847    1.971258    4.713711          0.000831
# 862    0.919644    7.257766          0.001658
# 871    2.594023   12.431548          0.001478
# 904    2.748782    4.006515          0.001248
# 956   13.285438    3.474697          0.002923

# %% [markdown]
# ### This is the third cluster.

# %%
km_2 = data[data["label"]==2]
km_2

from sklearn.linear_model import enet_path
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import lasso_path
from sklearn.linear_model import LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

X = km_2.drop(['Unnamed: 0', 'cases_total', 
       'deaths_total', 'cases_per_capita', 'deaths_per_capita',
       'case_fatality_rate', 'num_hospitals_pt',
       'num_licensed_beds_pt', 'num_staffed_beds_pt', 'num_icu_beds_pt',
       'adult_icu_beds_pt', 'pedi_icu_beds_pt',
       'potential_increase_in_bed_capac_pt', 'bed_utilization_pt',
       'avg_ventilator_usage_pt',"label"], axis=1)
Y = km_2['cases_per_capita']

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=263)

# 5-fold cross validation with lasso
np.random.seed(263)
lasso = Lasso(random_state=263, max_iter=100000, tol=0.0000001)
alphas = np.logspace(-5, -2, 30)
tuned_parameters = [{"alpha": alphas}]
n_folds = 5
clf = GridSearchCV(lasso, tuned_parameters, cv=n_folds)
clf.fit(X_train, y_train)
scores = clf.cv_results_["mean_test_score"]
scores_std = clf.cv_results_["std_test_score"]
# Best hyperparameter determined by lasso
print("The best hyperparameter chosen by lasso is {}.".format(clf.best_params_["alpha"]))

# First we import the necessary packages:
from itertools import cycle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import enet_path, lasso_path

eps = .01

alphas_lasso, coefs_lasso, _ = enet_path(
    X, Y, n_alphas = 10000, eps = eps, l1_ratio=1., fit_intercept=False)

plt.figure(1)
colors = cycle(['b', 'r', 'g', 'c', 'k'])
neg_log_alphas_lasso = np.log10(alphas_lasso)
for coef_l, c in zip(coefs_lasso, colors):
    l1 = plt.plot(neg_log_alphas_lasso, coef_l, c=c)
#    l2 = plt.plot(neg_log_alphas_ridge, coef_e, linestyle='--', c=c)

plt.xlabel('Log(alpha)')
plt.ylabel('coefficients')
plt.title('Lasso Paths')
plt.axis('tight')
plt.show()

# Top 30 important features determined by lasso
lm_lasso = Lasso(alpha=clf.best_params_["alpha"])
lm_lasso.fit(X_train, y_train)
coef_dict = {}
for coef, feat in zip(lm_lasso.coef_, X_train.columns):
    coef_dict[feat] = coef
print("The most important features determined by lasso are:")
allkm = sorted(coef_dict, key=coef_dict.get)[0:10]
print(allkm, "And the total samples in this cluster are:", len(X))

allkm = list(allkm)
allkm.append('cases_per_capita')
allkm
km_2 = km_2[km_2.columns & allkm]
#Examining to see if it makes sense.
km_2
# Out:
# The best hyperparameter chosen by lasso is 1.610262027560939e-05.
# The most important features determined by lasso are:
# ['65-74', 'X.500.gatherings', 'entertainment.gym', 'mob_parks', 'num_hospitals_pt.1', 'mob_grocery', 'potential_increase_in_bed_capac_pt.1', 'avg_ventilator_usage_pt.1', 'stay.at.home', 'Total!!Male'] And the total samples in this cluster are: 786
#       stay.at.home  X.500.gatherings  entertainment.gym  Total!!Male  \
# 0         1.389090         -1.090803           1.645564    -0.046878
# 1         1.389090         -1.090803           1.645564    -0.460164
# 2         1.389090         -1.090803           1.645564    -0.373842
# 3         1.389090         -1.090803           1.645564    -0.473402
# 4         1.389090         -1.090803           1.645564    -0.218976
# ...            ...               ...                ...          ...
# 1022      0.033195          0.359231          -0.272462    -0.418623
# 1023      0.033195          0.359231          -0.272462    -0.502818
# 1024      0.033195          0.359231          -0.272462    -0.279715
# 1025      0.033195          0.359231          -0.272462    -0.476283
# 1026      0.033195          0.359231          -0.272462    -0.322137
#
#       mob_grocery  mob_parks     65-74  cases_per_capita  num_hospitals_pt.1  \
# 0       -0.765298  -0.498468  0.166067          0.000842           -0.295633
# 1       -0.508957  -0.165632 -0.504940          0.001876            0.152923
# 2        0.571430   1.023299 -0.364897          0.000692           -0.388696
# 3       -0.451661   1.557132 -0.500517          0.005862            0.237699
# 4        0.356715  -0.111030 -0.183040          0.000924           -0.226262
# ...           ...        ...       ...               ...                 ...
# 1022     0.806954  -0.841063 -0.441094          0.003260           -0.234072
# 1023     0.463785   1.488900 -0.539951          0.001303            1.663590
# 1024    -0.321134   0.582644 -0.308061          0.001045           -0.524020
# 1025     0.976101  -0.787022 -0.519587          0.000303            1.534584
# 1026     1.035134   0.275291 -0.376330          0.000476            0.072735
#
#       potential_increase_in_bed_capac_pt.1  avg_ventilator_usage_pt.1
# 0                                -0.430859                  -0.737095
# 1                                -0.086634                  -0.058992
# 2                                -0.579607                  -0.240605
# 3                                 0.930402                   1.017112
# 4                                -0.093725                  -0.089529
# ...                                    ...                        ...
# 1022                             -0.213597                   0.069859
# 1023                             -0.184118                   1.457618
# 1024                             -0.136308                  -0.059762
# 1025                             -0.392435                   1.328104
# 1026                              0.049223                   0.135632
#
# [786 rows x 11 columns]

# %%
  #     plt.scatter(
  #         km_0[y_km == 0, 0], km_0[y_km == 0, 1],
  #         s=50, c='lightgreen',
  #         marker='s', edgecolor='black',
  #         label='cluster 1'
  #     )

  #     plt.scatter(
  #         X[y_km == 1, 0], X[y_km == 1, 1],
  #         s=50, c='orange',
  #         marker='o', edgecolor='black',
  #         label='cluster 2'
  #     )

  #     plt.scatter(
  #         X[y_km == 2, 0], X[y_km == 2, 1],
  #         s=50, c='lightblue',
  #         marker='v', edgecolor='black',
  #         label='cluster 3'
  #     )

  #     # plot the centroids
  #     plt.scatter(
  #         km.cluster_centers_[:, 0], km.cluster_centers_[:, 1],
  #         s=250, marker='*',
  #         c='red', edgecolor='black',
  #         label='centroids'
  #     )
  #     plt.legend(scatterpoints=1)
  #     plt.grid()
  #     plt.show()

# %% [markdown]
# # Now to run the random forest on each result.

# %% [markdown]
# ### Here is cluster 1

# %%
from sklearn.ensemble import RandomForestRegressor

km_0x = km_0.drop(['cases_per_capita'], axis=1)
km_0y = np.log(km_0["cases_per_capita"])


X_train, X_test, y_train, y_test = train_test_split(km_0x, km_0y, test_size=0.3, random_state=263)


np.random.seed(263)
Bs = [1, 2, 5, 10, 20, 50, 100, 200]
Rsqs = []
for B in Bs:
    regressor1 = RandomForestRegressor(n_estimators=B, max_depth=3)
    regressor1.fit(X_train, y_train)
    Rsqs.append(regressor1.score(X_train, y_train))
# Make the plot
plt.plot(list(map(str, Bs)), Rsqs, "-o")
plt.show()
max_Rsq = max(Rsqs)
max_index = Rsqs.index(max_Rsq)
print("\nmax R squared:", max_Rsq)
B = Bs[max_index]
B
regressor1 = RandomForestRegressor(n_estimators=3, max_depth=3, max_features=2, random_state=263, bootstrap=True)
regressor1.fit(X_train, y_train)
preds = regressor1.predict(X_test)
feature_list = list(km_0x.columns)
# Get numerical feature importances
importances = list(regressor1.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# max R squared: 0.6598346818528259
# Variable: entertainment.gym    Importance: 0.51
# Variable: stay.at.home         Importance: 0.23
# Variable: Pac Island           Importance: 0.14
# Variable: X.50.gatherings      Importance: 0.06
# Variable: Total                Importance: 0.03
# Variable: X.500.gatherings     Importance: 0.01
# Variable: restaurant.dine.in   Importance: 0.01
# Variable: public.schools       Importance: 0.0
# Variable: Total!!Male          Importance: 0.0
# Variable: Total!!Female        Importance: 0.0

# %%
from sklearn import metrics
km1_X = km_0.drop(["cases_per_capita"], axis = 1)
km1_y = np.log(km_0["cases_per_capita"])
X_train, X_test, y_train, y_test = train_test_split(km1_X, km1_y, test_size=0.2, random_state=263)

np.random.seed(263)

R2s = []

for i in range(1,200):
    regressor2 = RandomForestRegressor(n_estimators=i, max_depth=3, max_features=2, random_state=263)
    regressor2.fit(X_train, y_train)
    y_pre = regressor2.predict(X_test)
    R2s.append(metrics.r2_score(y_test, y_pre))
    
print("This is the max Rsq we achieve among all the esimators:", max(R2s))
print("This is the number of esimators that produces that Rsq:", int(R2s.index(max(R2s)))+1)
# Out:
# This is the max Rsq we achieve among all the esimators: 0.5027684824247816
# This is the number of esimators that produces that Rsq: 10

# %%
len(y_test)
# Out:
# 45

# %% [markdown]
# ### Here is cluster 2

# %%
km2_X = km_1.drop(["cases_per_capita"], axis=1)
km2_y = km_1["cases_per_capita"]
X_train, X_test, y_train, y_test = train_test_split(km2_X, km2_y, test_size=0.3, random_state=263)
np.random.seed(263)
Bs = [1, 2, 5, 10, 20, 50, 100, 200]
Rsqs = []
for B in Bs:
    regressor2 = RandomForestRegressor(n_estimators=B, max_depth=3, max_features=2)
    regressor2.fit(X_train, y_train)
    Rsqs.append(regressor2.score(X_train, y_train))
# Make the plot
plt.plot(list(map(str, Bs)), Rsqs, "-o")
plt.show()
max_Rsq = max(Rsqs)
max_index = Rsqs.index(max_Rsq)
print("\nmax R squared:", max_Rsq)
B = Bs[max_index]
B
regressor2 = RandomForestRegressor(n_estimators=B, max_depth=3, max_features=2)
regressor2.fit(X_train, y_train)
preds = regressor2.predict(X_test)
feature_list = list(km2_X.columns)
# Get numerical feature importances
importances = list(regressor2.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# max R squared: 0.969515393894428
# Variable: X.50.gatherings      Importance: 0.67
# Variable: dem_to_rep_ratio     Importance: 0.17
# Variable: stay.at.home         Importance: 0.09
# Variable: X.500.gatherings     Importance: 0.03
# Variable: entertainment.gym    Importance: 0.02
# Variable: Other Race           Importance: 0.01
# Variable: public.schools       Importance: 0.0
# Variable: restaurant.dine.in   Importance: 0.0
# Variable: Total!!Male          Importance: 0.0
# Variable: Pac Island           Importance: 0.0

# %%
km2_X = km_1.drop(["cases_per_capita"], axis = 1)
km2_y = np.log(km_1["cases_per_capita"])
X_train, X_test, y_train, y_test = train_test_split(km2_X, km2_y, test_size=0.2, random_state=263)

np.random.seed(263)

R2s = []

for i in range(1,200):
    regressor2 = RandomForestRegressor(n_estimators=i, max_depth=3, random_state=263)
    regressor2.fit(X_train, y_train)
    y_pre = regressor2.predict(X_test)
    R2s.append(metrics.r2_score(y_test, y_pre))
    
print("This is the max Rsq we achieve among all the esimators:", max(R2s))
print("This is the number of esimators that produces that Rsq:", int(R2s.index(max(R2s)))+1)
# Out:
# This is the max Rsq we achieve among all the esimators: 0.5392526599311374
# This is the number of esimators that produces that Rsq: 1

# %%
len(y_test)
# Out:
# 4

# %% [markdown]
# ### Finally, here is cluster 3, Random Forest.

# %%
km3_X = km_2.drop(["cases_per_capita"], axis=1)
km3_y = km_2["cases_per_capita"]
X_train, X_test, y_train, y_test = train_test_split(km3_X, km3_y, test_size=0.3, random_state=263)

np.random.seed(263)


Bs = [1, 2, 5, 10, 20, 50, 100, 200]
Rsqs = []
for B in Bs:
    regressor3 = RandomForestRegressor(n_estimators=B, max_depth=3)
    regressor3.fit(X_train, y_train)
    Rsqs.append(regressor3.score(X_train, y_train))
# Make the plot
plt.plot(list(map(str, Bs)), Rsqs, "-o")
plt.show()
max_Rsq = max(Rsqs)
max_index = Rsqs.index(max_Rsq)
print("\nmax R squared:", max_Rsq)
B = Bs[max_index]
B
regressor3 = RandomForestRegressor(n_estimators=B, max_depth=3)
regressor3.fit(X_train, y_train)
preds = regressor3.predict(X_test)
feature_list = list(km3_X.columns)
# Get numerical feature importances
importances = list(regressor3.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# max R squared: 0.3065655251478505
# Variable: mob_parks            Importance: 0.38
# Variable: num_hospitals_pt.1   Importance: 0.38
# Variable: entertainment.gym    Importance: 0.07
# Variable: potential_increase_in_bed_capac_pt.1 Importance: 0.07
# Variable: X.500.gatherings     Importance: 0.04
# Variable: stay.at.home         Importance: 0.03
# Variable: avg_ventilator_usage_pt.1 Importance: 0.03
# Variable: 65-74                Importance: 0.01
# Variable: Total!!Male          Importance: 0.0
# Variable: mob_grocery          Importance: 0.0

# %%
X_train, X_test, y_train, y_test = train_test_split(km3_X, km3_y, test_size=0.2, random_state=263)

np.random.seed(263)

R2s = []

for i in range(1,200):
    regressor2 = RandomForestRegressor(n_estimators=i, max_depth=3, random_state=263)
    regressor2.fit(X_train, y_train)
    y_pre = regressor2.predict(X_test)
    R2s.append(metrics.r2_score(y_test, y_pre))
    
print("This is the max Rsq we achieve among all the esimators:", max(R2s))
print("This is the number of esimators that produces that Rsq:", int(R2s.index(max(R2s)))+1)
# Out:
# This is the max Rsq we achieve among all the esimators: 0.19297440865167392
# This is the number of esimators that produces that Rsq: 6

# %%
len(y_test)
# Out:
# 158

# %% [markdown]
# # There it is, final results of Kmeans -> lasso -> randomforest pipeline.
